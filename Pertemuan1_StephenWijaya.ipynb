# %% [markdown]
# <a href="https://colab.research.google.com/github/Arachne01/data-science-2026/blob/main/Pertemuan1_StephenWijaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Data Science")
# Out:
# Hello, Data Science

# %%
nama = "Mahasiswa Informatika"
angkatan = "2024"
print(f"halo, {nama} angkatan {angkatan}!")
# Out:
# halo, Mahasiswa Informatika angkatan 2024!

# %%
tools = ["Phyton", "Colab", "Jupyter", "GitHub"]
for i, tool in enumerate(tools,1):
  print(f" {i}.{tool}")
# Out:
#  1.Phyton
#  2.Colab
#  3.Jupyter
#  4.GitHub

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Budi", "Informatika",2024))
# Out:
# Budi | Informatika | 2024
